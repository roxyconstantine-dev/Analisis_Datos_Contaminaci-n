# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyconstantine-dev/Analisis_Datos_Contaminaci-n/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV, learning_curve
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform
import statistics as stats
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
from sklearn.decomposition import KernelPCA
from sklearn.datasets import make_swiss_roll
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import plotly.express as px 
import pandas as pd
url="https://github.com/roxyconstantine-dev/Analisis_Datos_Contaminaci-n/blob/main/PRSA_Data.xlsx?raw=true"
df=pd.read_excel(url)
df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# ...     ...     ...   ...   ...  ...   ...           ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Aotizhongxin
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Aotizhongxin
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Aotizhongxin
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Aotizhongxin
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Aotizhongxin
#
# [35064 rows x 18 columns]

# %% [markdown]
# No:Número del dato
#
# year: Año del dato
#
# month:Mes del dato
#
# day: Dia del dato
#
# hour: Hora del dato
#
# PM2.5:  concentracion de particulas PM2.5 (ug/m^3)
#
# PM10: concentracion de particulas PM2.10 (ug/m^3)
#
# SO2: SO2 (ug/m^3)
#
# NO2: NO2  (ug/m^3)
#
# CO: CO  (ug/m^3)
#
# O3: O3  (ug/m^3)
#
# TEMP: temperatura (degree Celsius)
#
# PRES: presión (hPa)
#
# DEWP: dew point temperature (degree Celsius)
#
# RAIN: precipitation (mm)
#
# wd: wind direction
#
# WSPM: wind speed (m/s)
#
# station: name of the air-quality monitoring site

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# <ipython-input-4-6ac79f7ef903>:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df.info(verbose=True, null_counts=True)

# %% [markdown]
# Observando el comportamiento de los datos

# %%
df.hist(bins=10,figsize=(18,14),grid=False);

# %%
df.plot(kind='box', subplots=True, layout=(10,10), sharex=False, sharey=False, figsize=(30,30))
plt.show()

# %%
corr=df.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr, vmax=.8, linewidths=0.01,square=True,annot=False,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %% [markdown]
# Se observa una fuerte correlacion entre las particulas finas (PM2.5) y respirables (PM10) (el común mente llamado 'polvo fino') y el CO, la razon es que estas particulas provienen de procesos de combustión, actividades industriales o fuentes naturales. También se originan como resultado de la oxidación de contaminantes gaseosos en la atmósfera y su reacción con vapor de agua.

# %%
from scipy import stats
#histogram and normal probability plot
sns.distplot(crimes, hist=True);
fig = plt.figure()
res = stats.probplot(crimes, plot=plt)

# %%
plt.figure(figsize=(20, 5))

for i, col in enumerate(df.columns[0:6]):
    plt.subplot(1, 7, i+1)
    x = df[col]
    y = df['No']
    plt.plot(x, y, 'o')
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('crimes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: On entry to DLASCL parameter number 4 had an illegal value
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-11-2f72a350c1b0> in <module>
#       7     plt.plot(x, y, 'o')
#       8     # Create regression line
# ----> 9     plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
#      10     plt.title(col)
#      11     plt.xlabel(col)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in polyfit(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     666     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     667     lhs /= scale
# --> 668     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     669     c = (c.T/scale).T  # broadcast scale coefficients
#     670
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in lstsq(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2290         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2291         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2292     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2293     if m == 0:
#    2294         x[...] = 0
#
# /usr/local/lib/python3.8/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_lstsq(err, flag)
#      98
#      99 def _raise_linalgerror_lstsq(err, flag):
# --> 100     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     101
#     102 def _raise_linalgerror_qr(err, flag):
#
# SystemError: <class 'numpy.linalg.LinAlgError'> returned a result with an error set
